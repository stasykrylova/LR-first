# %%
import pylab
import matplotlib.patches as patches
import matplotlib.lines

def pup():
    pylab.xlim (-10, 10)
    pylab.ylim (-10, 10)
    pylab.rcParams['figure.figsize'] = [20, 20]
        # Получим текущие оси
    axes = pylab.gca()
    axes.set_aspect("equal")

    rect_coord = (-1.5, 1)
    rect_width = 0.5
    rect_height = 0.3
    rect_coord2 = (-9, -9)
    rect_width2 = 0.5
    rect_height2 = 0.3
    rect =patches.Rectangle (rect_coord,rect_width,rect_height, edgecolor='black',facecolor='none', linewidth = 3)
    rect2= patches.Rectangle (rect_coord2,rect_width2,rect_height2, edgecolor='black',facecolor='none', linewidth = 3)
    axes.add_patch (rect2)
    axes.add_patch (rect)
    line = matplotlib.lines.Line2D ([-1.5,-1], [0.5, 0.5], color="black")
    line2=matplotlib.lines.Line2D ([-1.45,-1.55,-1.45], [0.55, 0.5,0.45], color="black")
    line3=matplotlib.lines.Line2D ([-1.1,-1,-1.1], [0.55, 0.5,0.45], color="black")
    axes.add_line (line)
    axes.add_line (line2)
    axes.add_line (line3)
    pylab.text (-1.25, 0.2, "1L", horizontalalignment="center",size=15)          #"{}L".format(ДЛИНА) вместо 1 - конец+начало/2 2- низ-0.25 
    pylab.axis('off')
    
    pylab.savefig( 'image' )
    
    return pylab.figure()


pup().savefig('image2')
